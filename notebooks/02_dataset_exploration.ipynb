# %%
import pandas as pd

phishing = pd.read_csv(
    "../data/raw/cic_bell_dns2021/CSV_phishing.csv",
    on_bad_lines="skip"
)

print(phishing.shape)
print(phishing.columns)
print(phishing["Domain"].head(20))
print(phishing["Domain"].nunique())
# Out:
# (4939, 38)
# Index(['Country', 'ASN', 'TTL', 'IP', 'Domain', 'Name_Server_Count',
#        'Domain_Age', 'entropy', 'hex_8', 'numeric_percentage', '1gram',
#        'typos', 'tld', 'char_distribution', 'subdomain', 'puny_coded',
#        'Organization', 'Country.1', 'longest_word', 'dec_8', 'dec_32',
#        'Registrant_Name', 'sld', 'shortened', '2gram', 'oc_8', 'State',
#        'Registrar', 'hex_32', 'Page_Rank', 'oc_32', 'Alexa_Rank', 'len',
#        'obfuscate_at_sign', 'Emails', '3gram', 'Domain_Name',
#        'Creation_Date_Time'],
#       dtype='str')
# ...

# %%
for name, df in {
    "phishing": phishing,
    "benign": benign,
    "malware": malware,
    "spam": spam
}.items():
    print(name, df.shape)
